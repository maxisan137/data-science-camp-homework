# %% [markdown]
# # Lesson 3 Homework
# ### By: Maksym Lushpak

# %%
import pandas as pd

# %% [markdown]
# ## Question 1

# %% [markdown]
# Prepare Energy Indicators dataset:

# %%
energy = pd.read_excel("Energy Indicators.xls", header=None) # Load Excel sheet

energy = energy.loc[18:243] # Remove unwanted rows
energy = energy.drop([0, 1], axis = 1) # Remove unwanted columns
energy.columns = ["Country", "Energy Supply", "Energy Supply per Capita", "% Renewable"] # add header

# Replace non-numeric values with NaN
for col in energy.columns[1:]:
    energy[col] = pd.to_numeric(energy[col], errors="coerce")

# Convert Energy Supply to Gigajouls
energy["Energy Supply"] *= 1e6

# Remove name parts that are in parenthesis
energy["Country"] = energy["Country"].apply(lambda name: name.split(" (")[0])

# Remove numbers from country names
energy["Country"] = energy["Country"].apply(lambda name: "".join(char for char in name if not char.isdigit()))

# Renaming certain countries
countries_rename = [
    {"old": "Republic of Korea", "new": "South Korea"},
    {"old": "United States of America", "new": "United States"},
    {"old": "United Kingdom of Great Britain and Northern Ireland", "new": "United Kingdom"},
    {"old": "China, Hong Kong Special Administrative Region", "new": "Hong Kong"}
]
for names in countries_rename:
    energy.loc[energy["Country"] == names["old"], "Country"] = names["new"]

energy
# Out:
#                        Country  Energy Supply  Energy Supply per Capita  \
# 18                 Afghanistan   3.210000e+08                      10.0
# 19                     Albania   1.020000e+08                      35.0
# 20                     Algeria   1.959000e+09                      51.0
# 21              American Samoa            NaN                       NaN
# 22                     Andorra   9.000000e+06                     121.0
# ..                         ...            ...                       ...
# 239                  Venezuela   2.871000e+09                      95.0
# 240                   Viet Nam   2.554000e+09                      28.0
# 241  Wallis and Futuna Islands   0.000000e+00                      26.0
# 242                      Yemen   3.440000e+08                      13.0
# 243                     Zambia   4.000000e+08                      26.0
#
#      % Renewable
# 18     78.669280
# 19    100.000000
# 20      0.551010
# 21      0.641026
# ...

# %% [markdown]
# Prepare World Bank GDP dataset:

# %%
GDP = pd.read_csv("world_bank.csv", skiprows=4) # Load CSV

# Renaming certain countries
countries_rename = [
    {"old": "Korea, Rep.", "new": "South Korea"},
    {"old": "Iran, Islamic Rep.", "new": "Iran"},
    {"old": "Hong Kong SAR, China", "new": "Hong Kong"}
]
for names in countries_rename:
    GDP.loc[GDP["Country Name"] == names["old"], "Country Name"] = names["new"]

GDP
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 2                    Afghanistan          AFG  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  GDP (current US$)
# 262                  Yemen, Rep.          YEM  GDP (current US$)
# 263                 South Africa          ZAF  GDP (current US$)
# 264                       Zambia          ZMB  GDP (current US$)
# 265                     Zimbabwe          ZWE  GDP (current US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# ...

# %% [markdown]
# Prepare Sciamo Journal dataset:

# %%
ScimEn = pd.read_excel("scimagojr.xlsx")

ScimEn
# Out:
#      Rank                   Country            Region  Documents  \
# 0       1                     China    Asiatic Region     273437
# 1       2             United States  Northern America     175891
# 2       3                     India    Asiatic Region      55082
# 3       4                     Japan    Asiatic Region      50523
# 4       5            United Kingdom    Western Europe      43389
# ..    ...                       ...               ...        ...
# 203   204                   Comoros            Africa          1
# 204   205    Svalbard and Jan Mayen    Western Europe          1
# 205   206                     Palau    Pacific Region          1
# 206   207                   Bahamas     Latin America          1
# 207   208  Central African Republic            Africa          1
#
#      Citable documents  Citations  Self-citations  Citations per document  \
# 0               272374    2336764         1615239                    8.55
# ...

# %% [markdown]
# Joining datasets:

# %%
def answer_one():

    answer_header = ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']

    answer = pd.DataFrame(columns=answer_header[1:1])
    answer["Rank"] = ScimEn["Rank"][:15]
    answer.index = ScimEn["Country"][:15]

    for col_name in answer_header[1:]:
        if col_name in ScimEn.columns:
            answer = pd.merge(answer, ScimEn[["Country", col_name]], left_index=True, right_on="Country", how="left").set_index(answer.index).drop("Country", axis=1)

    for col_name in answer_header:
        if col_name in energy.columns:
            answer = pd.merge(answer, energy[["Country", col_name]], left_index=True, right_on="Country", how="left").set_index(answer.index).drop("Country", axis=1)

    for col_name in answer_header:
        if col_name in GDP.columns:
            answer = pd.merge(answer, GDP[["Country Name", col_name]], left_index=True, right_on="Country Name", how="left").set_index(answer.index).drop("Country Name", axis=1)

    return answer

answer_one()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     273437             272374    2336764
# United States          2     175891             172431    2230544
# India                  3      55082              53775     463165
# Japan                  4      50523              50065     488062
# United Kingdom         5      43389              42284     615670
# Germany                6      38739              38013     433148
# Russian Federation     7      36735              36560     115938
# Canada                 8      33472              32863     568080
# Italy                  9      27983              26940     352993
# South Korea           10      27655              27445     328488
# France                11      25232              24732     343860
# Iran                  12      22933              22734     307280
# Spain                 13      21955              21597     352497
# ...

# %% [markdown]
# ## Question 2

# %%
def answer_two():
    top15 = answer_one()
    start_year = 2006
    years = 10
    return sum(top15[str(i)] for i in range(start_year, start_year + years)) / years

answer_two()
# Out:
# Country
# China                 6.927707e+12
# United States         1.570403e+13
# India                 1.602352e+12
# Japan                 5.239642e+12
# United Kingdom        2.780276e+12
# Germany               3.523342e+12
# Russian Federation    1.666746e+12
# Canada                1.616359e+12
# Italy                 2.142986e+12
# South Korea           1.221372e+12
# France                2.691337e+12
# Iran                  4.563261e+11
# Spain                 1.400886e+12
# Brazil                1.988889e+12
# Australia             1.207513e+12
# dtype: float64

# %% [markdown]
# ## Question 3

# %%
def answer_three():
    country = answer_two().nlargest(6).index[-1]
    country_row = answer_one().loc[country]
    return country_row["2015"] - country_row["2006"]

answer_three()
# Out:
# 118652421857.7998

# %% [markdown]
# ## Question 4

# %%
def answer_four():
    top15 = answer_one()
    top15["Self-Citations Ratio"] = top15["Self-citations"] / top15["Citations"]
    largest = top15["Self-Citations Ratio"].nlargest(1)
    return (largest[0], largest.index[-1])

answer_four()
# Out:
# (0.6912289816173135, 'China')

# %% [markdown]
# ## Question 5

# %%
def answer_five():
    top15 = answer_one()
    top15["Population"] = top15["Energy Supply"] / top15["Energy Supply per Capita"]
    return top15["Population"].nlargest(3).index[-1]

answer_five()
# Out:
# 'United States'

# %% [markdown]
# ## Question 6

# %%
def answer_six():
    top15 = answer_one()
    top15["Citable Documents per Capita"] = top15["Citable documents"] / top15["Energy Supply"] * top15["Energy Supply per Capita"]
    return top15["Citable Documents per Capita"].corr(top15["Energy Supply per Capita"])

answer_six()
# Out:
# 0.7434709127726776

# %% [markdown]
# ## Question 7

# %%
continentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}

def answer_seven():

    top15 = answer_one()
    top15["Population"] = top15["Energy Supply"] / top15["Energy Supply per Capita"]

    cont_names = []
    for key in continentDict.keys():
        cont = continentDict[key]
        if cont not in cont_names: cont_names.append(cont)

    top15["Continent"] = top15.index.to_series().apply(lambda c: continentDict[c])

    continents = pd.DataFrame(columns=['size', 'sum', 'mean', 'std'])
    for continent in cont_names:
        cont_rows = top15[top15["Continent"] == continent]
        size = len(cont_rows)
        popul_sum = sum([top15.loc[country]["Population"] for country in cont_rows.index])
        mean = popul_sum / size
        std_dev = (sum([(top15.loc[country]["Population"] - mean)**2 for country in cont_rows.index])/size)**0.5

        continents.loc[continent] = [size, popul_sum, mean, std_dev]
    
    return continents

answer_seven()
# Out:
#                size           sum          mean           std
# Asia            5.0  2.898666e+09  5.797333e+08  6.074036e+08
# North America   2.0  3.528552e+08  1.764276e+08  1.411878e+08
# Europe          6.0  4.579297e+08  7.632161e+07  3.162885e+07
# Australia       1.0  2.331602e+07  2.331602e+07  0.000000e+00
# South America   1.0  2.059153e+08  2.059153e+08  0.000000e+00
